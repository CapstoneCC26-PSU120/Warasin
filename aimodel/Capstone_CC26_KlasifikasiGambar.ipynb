# %% [markdown]
# # **Model Deteksi Emosi Wajah**
# ## Warasin — AI Engineer
# ---

# %% [markdown]
# ## Import Library
# ---

# %%
import pandas as pd

# %% [markdown]
# ## Load Dataset
# ---

# %% [markdown]
# ## Model CNN (Functional API)
# ---

# %% [markdown]
# ## Custom Loss Function
# ---

# %% [markdown]
# ## Training Model
# ---

# %% [markdown]
# ## Evaluasi Model
# ---

# %% [markdown]
# ## Save Model
# ---
